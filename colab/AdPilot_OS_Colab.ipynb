# %% [markdown]
# # AdPilot OS — Colab runner
# Run the AdPilot OS engine (Meta & TikTok ads health check) in Google Colab — no install, no API keys. The engine is pure Python standard library.
#
# **What you can do here:** verify the engine (56/56 self-test), analyse the sample accounts, and analyse **your own** Meta/TikTok CSV export — all read-only. It never touches a live ad.
#
# Share this notebook to give someone a hands-on demo. To share the *private* source with a specific person, prefer a GitHub collaborator invite; this notebook works with the public repo (or a token, see the clone cell).

# %% [markdown]
# ## 1. Get the engine

# %%
# Public repo:
# !git clone --depth 1 https://github.com/edagher92-coder/SOCIALAUTOMATION.git
# Private repo? Use a fine-grained token with read access instead:
# !git clone --depth 1 https://USERNAME:TOKEN@github.com/edagher92-coder/SOCIALAUTOMATION.git
# %cd SOCIALAUTOMATION/CPWORK/universal-ads-os/tools

# %% [markdown]
# ## 2. Verify the engine (self-test)

# %%
# !python3 -m adpilot selftest

# %% [markdown]
# ## 3. Analyse the sample accounts (clean / fatigued / broken)

# %%
for s in ['clean_account', 'fatigued_account', 'broken_tracking']:
    print('='*70, '\n', s, '\n', '='*70)
    # !python3 -m adpilot analyze adpilot/tests/fixtures/{s}.csv --avg-sale 200 --margin 0.6

# %% [markdown]
# ## 4. Analyse YOUR Meta/TikTok export
# Run the cell, upload a CSV (Meta Ads Manager / TikTok Ads Manager export, or the universal format), and set your average sale value and gross margin.

# %%
from google.colab import files
AVG_SALE = 200   # your average sale value (AUD)
GROSS_MARGIN = 0.6  # 0..1
up = files.upload()
name = list(up.keys())[0]
# !python3 -m adpilot analyze "{name}" --avg-sale {AVG_SALE} --margin {GROSS_MARGIN}

# %% [markdown]
# ---
# Read-only analysis. Figures are illustrative; no earnings or results guarantees. Full system, web app, and V2 PRD: see the repo under `CPWORK/universal-ads-os/` and `adpilot-v2/`.
